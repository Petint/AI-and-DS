# %% [markdown]
# # DS-3

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
train_smal = pd.read_csv('3lessonData/train_small.csv')
test_smal = pd.read_csv('3lessonData/test_small.csv')

# %%
train_smal.head()
# Out:
#     x          y
# 0  24  21.549452
# 1  50  47.464463
# 2  15  17.218656
# 3  38  36.586398
# 4  87  87.288984

# %%
x_ts = train_smal.iloc[:, 0].values.reshape(-1, 1)
y_ts = train_smal.iloc[:, 1].values.reshape(-1, 1)

x_tt = test_smal.iloc[:, 0].values.reshape(-1, 1)
y_tt = test_smal.iloc[:, 1].values.reshape(-1, 1)

# %% [markdown]
# ## Plot data

# %%
plt.scatter(x_ts, y_ts)

# %%
from sklearn.linear_model import LinearRegression
mod_sm = LinearRegression()
mod_sm.fit(y_ts, x_ts)
# Out:
# LinearRegression()

# %%
y_pred_sm = mod_sm.predict(x_ts)
plt.scatter(x_tt, y_tt, color="lightblue")
plt.plot(x_ts, y_pred_sm, color='red', linewidth=3)

# %%
rsq = mod_sm.score(x_tt, y_tt)
print(f'cod: {rsq}')
# Out:
# cod: 0.9885041104954638

# %% [markdown]
# ## Predict age

# %%
dh = pd.read_csv('3lessonData/body_measures.csv')
dh.columns
dh.head
# Out:
# <bound method NDFrame.head of      Gender  Age  HeadCircumference  ShoulderWidth  ChestWidth  Belly  Waist  \
# 0       1.0   30                 22             18          20     18     14
# 1       1.0   28                 19             22          17     18     21
# 2       2.0   27                 21             18          16     14     10
# 3       1.0   29                 20             20          18     11     19
# 4       2.0   28                 16             14          18     13     11
# ..      ...  ...                ...            ...         ...    ...    ...
# 711     2.0   13                 22              6          14     25     18
# 712     1.0   10                 21             11          12     22      2
# 713     1.0    4                 20             17          11     22     22
# 714     1.0   13                 20             15          14     25     18
# 715     2.0    4                 20             15          10     20     20
#
# ...

# %% [markdown]
# ### 'Washing machine'

# %%
dh.isna().sum()
dh = dh.dropna()

# %%
import seaborn as sb
plt.figure(figsize=(10, 10), dpi=800)
df = pd.DataFrame(dh, columns=dh.columns)
corrMatrix = df.corr()
sb.heatmap(corrMatrix, annot=True)
# Out:
# <AxesSubplot: >

# %%
# dh = dh.drop['ShoulderToWaist', 'WaistToKnee']

# %% [markdown]
# ### make model

# %%
x = dh[dh.columns.drop('Age')]
y = df['Age']
